# %% [markdown]
# <a href="https://colab.research.google.com/github/Darshini5/C/blob/main/Automated_Image_Colorization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/harrison8989/recolorizer.git
# Out:
# Cloning into 'recolorizer'...
# remote: Enumerating objects: 172, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 172 (delta 3), reused 1 (delta 0), pack-reused 163 (from 1)
# Receiving objects: 100% (172/172), 748.16 KiB | 13.60 MiB/s, done.
# Resolving deltas: 100% (88/88), done.

# %%
# %cd recolorizer
# Out:
# /content/recolorizer

# %%
# !pip install numpy opencv-python scikit-image scikit-learn matplotlib

# %%
#!python train_svr.py data/train
# !python train_svr.py -t data/train -f svr.model
#python train_svr.py -t data/train -f svr.model
#!python train_svr.py --training_set data/train --output_file svr.model
# Out:
#   File "/content/recolorizer/train_svr.py", line 76
#     print 'Training data set on files in:', args.t
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
#!python test_svr.py data/test/BW1.jpg
# !python test_svr.py data/test/BW4.jpg -f svr.model -s result.png
# Out:
#   File "/content/recolorizer/recolorizer/test_svr.py", line 171
#     print 'Norm error:', error
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
ls data/test
# Out:
# ls: cannot access 'data/test': No such file or directory

# %%
# !python -m lib2to3 -w train_svr.py
# !python -m lib2to3 -w test_svr.py
# !python -m lib2to3 -w segment_images.py
# !python -m lib2to3 -w
# Out:
# /usr/bin/python3: No module named lib2to3
# /usr/bin/python3: No module named lib2to3
# /usr/bin/python3: No module named lib2to3
# /usr/bin/python3: No module named lib2to3

# %%
pip install joblib
